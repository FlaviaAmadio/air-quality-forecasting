# %%
import pandas as pd
# Out:
# /tmp
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/numpy
# /usr/share/zoneinfo

# %%
from src.transform import make_clean_no2_timeseries

# %%
df = pd.read_csv("../data/air_quality.csv")

# %%
df_ts = make_clean_no2_timeseries(
    df,
    station_id=42,
    pollutant_code=8,
)

# %%
df_ts.head()
# Out:
#                      station   NO2 valid_flag  NO2_clean
# datetime
# 2026-01-18 00:00:00       42  18.0          V       18.0
# 2026-01-18 01:00:00       42  15.0          V       15.0
# 2026-01-18 02:00:00       42  17.0          V       17.0
# 2026-01-18 03:00:00       42  27.0          V       27.0
# 2026-01-18 04:00:00       42  29.0          V       29.0
