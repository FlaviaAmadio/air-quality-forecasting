# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
# Out:
# /tmp
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/numpy
# /usr/share/zoneinfo
# /home/flavia/.config/matplotlib
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/.config/matplotlib

# %% [markdown]
# Checking metadata

# %%
md_contaminants = pd.read_csv('../data/qualitat_aire_contaminants.csv')
md_stations = pd.read_csv('../data/2025_qualitat_aire_estacions.csv')
md_stations['Estacio'].unique()
# Out:
# array([ 4, 42, 43, 44, 50, 54, 57, 58])

# %%
md_42 = md_stations[md_stations['Estacio'] == 42]
md_42.head()
# Out:
#    Estacio         nom_cabina codi_dtes  zqa  codi_eoi  Longitud  Latitud  \
# 4       42  Barcelona - Sants        ID    1   8019042    2.1331  41.3788
# 5       42  Barcelona - Sants        ID    1   8019042    2.1331  41.3788
# 6       42  Barcelona - Sants        ID    1   8019042    2.1331  41.3788
#
#                                             ubicacio  Codi_districte  \
# 4  Jardins de Can Mantega (Joan Güell - Violant d...               3
# 5  Jardins de Can Mantega (Joan Güell - Violant d...               3
# 6  Jardins de Can Mantega (Joan Güell - Violant d...               3
#
#     Nom_districte  Codi_barri Nom_barri  Clas_1 Clas_2  Codi_Contaminant
# 4  Sants-Montjuic          18     Sants  Urbana   Fons                 8
# 5  Sants-Montjuic          18     Sants  Urbana   Fons                 7
# 6  Sants-Montjuic          18     Sants  Urbana   Fons                12

# %% [markdown]
# The dataset encodes pollutants using numeric identifiers. According to the official metadata provided by Barcelona Open Data, code 8 corresponds to Nitrogen Dioxide (NO2), which was selected for this analysis due to its relevance to urban air quality and health.

# %% [markdown]
# Checking dataset

# %%
df = pd.read_csv("../data/air_quality.csv")
df.head()
# Out:
#    CODI_PROVINCIA  PROVINCIA  CODI_MUNICIPI   MUNICIPI  ESTACIO  \
# 0               8  Barcelona             19  Barcelona       43
# 1               8  Barcelona             19  Barcelona       43
# 2               8  Barcelona             19  Barcelona       43
# 3               8  Barcelona             19  Barcelona       43
# 4               8  Barcelona             19  Barcelona       54
#
#    CODI_CONTAMINANT   ANY  MES  DIA   H01  ...   H20  V20   H21  V21   H22  \
# 0               999  2026    1   18  19.2  ...  21.7    V  25.7    V  26.0
# 1               999  2026    1   19  22.6  ...  22.4    V  19.2    V  13.7
# 2               999  2026    1   20  24.5  ...  21.0    V  18.8    V  20.9
# 3               999  2026    1   21  23.4  ...   NaN    N   NaN    N   NaN
# 4               999  2026    1   18  27.0  ...  25.4    V  23.6    V  23.6
#
#    V22   H23  V23   H24  V24
# 0    V  25.7    V  26.3    V
# 1    V  19.1    V  21.0    V
# 2    V  19.7    V  22.7    V
# 3    N   NaN    N   NaN    N
# 4    V  29.8    V  28.0    V
#
# [5 rows x 57 columns]

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 316 entries, 0 to 315
# Data columns (total 57 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   CODI_PROVINCIA    316 non-null    int64
#  1   PROVINCIA         316 non-null    object
#  2   CODI_MUNICIPI     316 non-null    int64
#  3   MUNICIPI          316 non-null    object
#  4   ESTACIO           316 non-null    int64
#  5   CODI_CONTAMINANT  316 non-null    int64
#  6   ANY               316 non-null    int64
#  7   MES               316 non-null    int64
#  8   DIA               316 non-null    int64
#  9   H01               312 non-null    float64
#  10  V01               316 non-null    object
#  11  H02               312 non-null    float64
#  12  V02               316 non-null    object
#  13  H03               312 non-null    float64
#  14  V03               316 non-null    object
#  15  H04               312 non-null    float64
#  16  V04               316 non-null    object
#  17  H05               312 non-null    float64
#  18  V05               316 non-null    object
#  19  H06               312 non-null    float64
#  20  V06               316 non-null    object
#  21  H07               312 non-null    float64
#  22  V07               316 non-null    object
#  23  H08               312 non-null    float64
#  24  V08               316 non-null    object
#  25  H09               312 non-null    float64
#  26  V09               316 non-null    object
#  27  H10               304 non-null    float64
#  28  V10               316 non-null    object
#  29  H11               289 non-null    float64
#  30  V11               316 non-null    object
#  31  H12               287 non-null    float64
#  32  V12               316 non-null    object
#  33  H13               297 non-null    float64
#  34  V13               316 non-null    object
#  35  H14               305 non-null    float64
#  36  V14               316 non-null    object
#  37  H15               311 non-null    float64
#  38  V15               316 non-null    object
#  39  H16               234 non-null    float64
#  40  V16               316 non-null    object
#  41  H17               234 non-null    float64
#  42  V17               316 non-null    object
#  43  H18               234 non-null    float64
#  44  V18               316 non-null    object
#  45  H19               234 non-null    float64
#  46  V19               316 non-null    object
#  47  H20               234 non-null    float64
#  48  V20               316 non-null    object
#  49  H21               234 non-null    float64
#  50  V21               316 non-null    object
#  51  H22               234 non-null    float64
#  52  V22               316 non-null    object
#  53  H23               234 non-null    float64
#  54  V23               316 non-null    object
#  55  H24               234 non-null    float64
#  56  V24               316 non-null    object
# dtypes: float64(24), int64(7), object(26)
# memory usage: 140.8+ KB
#        CODI_PROVINCIA  CODI_MUNICIPI     ESTACIO  CODI_CONTAMINANT     ANY  \
# count           316.0          316.0  316.000000        316.000000   316.0
# mean              8.0           19.0  143.430380        180.696203  2026.0
# std               0.0            0.0  265.149383        357.888246     0.0
# min               8.0           19.0    4.000000          1.000000  2026.0
# 25%               8.0           19.0   43.000000          8.000000  2026.0
# 50%               8.0           19.0   54.000000         11.000000  2026.0
# 75%               8.0           19.0   57.000000        107.000000  2026.0
# max               8.0           19.0  881.000000        999.000000  2026.0
#
#          MES         DIA          H01          H02         H03  ...  \
# count  316.0  316.000000   312.000000   312.000000   312.00000  ...
# mean     1.0   19.500000   282.107083   278.087532   276.69875  ...
# std      0.0    1.119807  1001.283850  1001.503853  1001.58492  ...
# min      1.0   18.000000     0.000000     0.000000    -0.02000  ...
# 25%      1.0   18.750000     2.112500     2.000000     1.00000  ...
# 50%      1.0   19.500000     8.300000     6.000000     5.81500  ...
# 75%      1.0   20.250000    28.325000    32.175000    29.65000  ...
# max      1.0   21.000000  4999.000000  4999.000000  4999.00000  ...
#
#                H15          H16          H17          H18          H19  \
# count   311.000000   234.000000   234.000000   234.000000   234.000000
# mean    298.837428   295.223077   294.901880   298.306880   299.552521
# std    1008.812675  1007.181315  1005.836582  1007.922424  1007.896011
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       2.000000     3.000000     3.000000     3.000000     3.235000
# 50%      13.000000    10.850000    12.000000    12.000000    12.855000
# 75%      38.000000    37.500000    36.750000    37.500000    36.750000
# max    4999.000000  4999.000000  4999.000000  4999.000000  4999.000000
#
#                H20          H21          H22          H23          H24
# count   234.000000   234.000000   234.000000   234.000000   234.000000
# mean    296.590128   291.151068   291.451709   286.824658   285.904359
# std    1005.569131  1003.874757  1004.034117  1002.075866  1002.247690
# min       0.000000    -0.020000     0.000000     0.000000    -0.030000
# 25%       4.000000     2.307500     3.000000     3.000000     3.000000
# 50%      11.005000    12.000000    10.000000    10.000000     9.000000
# 75%      36.000000    27.000000    36.000000    34.250000    32.775000
# max    4999.000000  4999.000000  4999.000000  4999.000000  4999.000000
#
# [8 rows x 31 columns]

# %% [markdown]
# Identify NO2 and select the relevant column. Identify a station (This case is Barcelona Sants)

# %%
df.columns
# Out:
# Index(['CODI_PROVINCIA', 'PROVINCIA', 'CODI_MUNICIPI', 'MUNICIPI', 'ESTACIO',
#        'CODI_CONTAMINANT', 'ANY', 'MES', 'DIA', 'H01', 'V01', 'H02', 'V02',
#        'H03', 'V03', 'H04', 'V04', 'H05', 'V05', 'H06', 'V06', 'H07', 'V07',
#        'H08', 'V08', 'H09', 'V09', 'H10', 'V10', 'H11', 'V11', 'H12', 'V12',
#        'H13', 'V13', 'H14', 'V14', 'H15', 'V15', 'H16', 'V16', 'H17', 'V17',
#        'H18', 'V18', 'H19', 'V19', 'H20', 'V20', 'H21', 'V21', 'H22', 'V22',
#        'H23', 'V23', 'H24', 'V24'],
#       dtype='object')

# %%
df['CODI_CONTAMINANT'].unique()
# Out:
# array([999,  22,   6, 106, 997, 996, 998,   7, 107,   8, 108,  12, 112,
#        995,  14, 114,  11, 111,  10, 110,   9, 109, 901,   1, 101])

# %%
df['ESTACIO'].unique()
# Out:
# array([ 43,  54,  57,  50,  44,  58,   4,  42, 881])

# %%
df_no2 = df[df['CODI_CONTAMINANT'] == 8]
df_station = df_no2[df_no2['ESTACIO'] == 42]
df_station.head()
# Out:
#      CODI_PROVINCIA  PROVINCIA  CODI_MUNICIPI   MUNICIPI  ESTACIO  \
# 120               8  Barcelona             19  Barcelona       42
# 121               8  Barcelona             19  Barcelona       42
# 122               8  Barcelona             19  Barcelona       42
# 123               8  Barcelona             19  Barcelona       42
#
#      CODI_CONTAMINANT   ANY  MES  DIA   H01  ...   H20  V20   H21  V21   H22  \
# 120                 8  2026    1   18  18.0  ...  28.0    V  19.0    V  17.0
# 121                 8  2026    1   19  18.0  ...  25.0    V  22.0    V  17.0
# 122                 8  2026    1   20   6.0  ...  24.0    V  20.0    V  20.0
# 123                 8  2026    1   21  13.0  ...   NaN    N   NaN    N   NaN
#
#      V22   H23  V23   H24  V24
# 120    V  15.0    V  16.0    V
# 121    V  11.0    V   8.0    V
# 122    V  24.0    V  17.0    V
# 123    N   NaN    N   NaN    N
#
# [4 rows x 57 columns]

# %% [markdown]
# Unpivot hour columns and reshape dataset

# %%
value_cols = [f'H{i:02d}' for i in range(1, 25)]
flag_cols  = [f'V{i:02d}' for i in range(1, 25)]

df_values = df_station.melt(
    id_vars=['ANY', 'MES', 'DIA', 'ESTACIO'],
    value_vars=value_cols,
    var_name='hour',
    value_name='NO2'
)
df_values['hour'] = df_values['hour'].str[1:].astype(int) - 1

df_flags = df_station.melt(
    id_vars=['ANY', 'MES', 'DIA', 'ESTACIO'],
    value_vars=flag_cols,
    var_name='hour',
    value_name='valid_flag'
)
df_flags['hour'] = df_flags['hour'].str[1:].astype(int) - 1

# %%
df_long = (df_long[['datetime', 'ESTACIO', 'NO2', 'NO2_clean', 'valid_flag']]
           .rename(columns={'ESTACIO': 'station'})
           .sort_values('datetime'))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_17844/3900098844.py in <module>
# ----> 1 df_long = (df_long[['datetime', 'ESTACIO', 'NO2', 'NO2_clean', 'valid_flag']]
#       2            .rename(columns={'ESTACIO': 'station'})
#       3            .sort_values('datetime'))
#
# ~/anaconda3/envs/astroconda/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3462             if is_iterator(key):
#    3463                 key = list(key)
# -> 3464             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3465
#    3466         # take() does not accept boolean indexers
#
# ~/anaconda3/envs/astroconda/lib/python3.7/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
#    1316         if needs_i8_conversion(ax.dtype) or isinstance(
#
# ~/anaconda3/envs/astroconda/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis)
#    1375
#    1376             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 1377             raise KeyError(f"{not_found} not in index")
#    1378
#    1379
#
# KeyError: "['datetime', 'NO2_clean'] not in index"

# %%
# Out:
# /home/flavia/Portfolio/ML_projects/air-quality-forecasting/notebooks
# /home/flavia/Portfolio/ML_projects/air-quality-forecasting/notebooks
# /home/flavia/Portfolio/ML_projects/air-quality-forecasting/notebooks
# /home/flavia/Portfolio/ML_projects/air-quality-forecasting/notebooks
# /home/flavia/Portfolio/ML_projects/air-quality-forecasting/notebooks
# /home/flavia/Portfolio/ML_projects/air-quality-forecasting/notebooks
# /home/flavia/Portfolio/ML_projects/air-quality-forecasting/notebooks
# /home/flavia/Portfolio/ML_projects/air-quality-forecasting/notebooks
# /home/flavia/Portfolio/ML_projects/air-quality-forecasting/notebooks
# /home/flavia/anaconda3/envs/astroconda/lib/python37.zip
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/lib-dynload
#
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages
# /home/flavia/Portfolio/ML_projects/air-quality-forecasting/notebooks
# /home/flavia/anaconda3/envs/astroconda/lib/python37.zip
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/lib-dynload
#
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages
# /home/flavia/Portfolio/ML_projects/air-quality-forecasting/notebooks
# /home/flavia/anaconda3/envs/astroconda/lib/python37.zip
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/lib-dynload
#
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/picaso-3.2-py3.7.egg
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/virga_exo-0.4-py3.7.egg
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/shapely-2.0.4-py3.7-linux-x86_64.egg
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/fonttools-4.53.0-py3.7.egg
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/PyMieScatt-1.8.1.1-py3.7.egg
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/IPython/extensions
# /home/flavia/.ipython
# /home/flavia/Portfolio/ML_projects/air-quality-forecasting/notebooks
# /home/flavia/anaconda3/envs/astroconda/lib/python37.zip
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/lib-dynload
#
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/picaso-3.2-py3.7.egg
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/virga_exo-0.4-py3.7.egg
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/shapely-2.0.4-py3.7-linux-x86_64.egg
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/fonttools-4.53.0-py3.7.egg
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/PyMieScatt-1.8.1.1-py3.7.egg
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/IPython/extensions
# /home/flavia/.ipython
# /home/flavia/Portfolio/ML_projects/air-quality-forecasting/notebooks
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/astroconda/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/anaconda3/envs/astroconda/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/anaconda3/envs/astroconda/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ANY'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_17844/3300793003.py in <module>
#       1 df_long['datetime'] = pd.to_datetime(
#       2     dict(
# ----> 3         year=df_long['ANY'],
#       4         month=df_long['MES'],
#       5         day=df_long['DIA'],
#
# ~/anaconda3/envs/astroconda/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~/anaconda3/envs/astroconda/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'ANY'

# %% [markdown]
# Plot NO2 concentration in sants in January

# %%
plt.figure(figsize=(14, 5))

plt.plot(
    df_long['datetime'],
    df_long['NO2'],
    label='NO₂ (raw)',
    alpha=0.3
)

plt.plot(
    df_long['datetime'],
    df_long['NO2_clean'],
    label='NO₂ (clean)',
    linewidth=1.5
)

plt.xlabel('Datetime')
plt.ylabel('NO₂ concentration')
plt.title('Raw vs Cleaned NO₂ Measurements')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# /
# /home
# /home/flavia
# /home/flavia/anaconda3
# /home/flavia/anaconda3/envs
# /home/flavia/anaconda3/envs/astroconda
# /home/flavia/anaconda3/envs/astroconda/lib
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data/fonts
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/mpl-data/fonts/ttf
# /
# /home
# /home/flavia
# /home/flavia/anaconda3
# /home/flavia/anaconda3/envs
# /home/flavia/anaconda3/envs/astroconda
# /home/flavia/anaconda3/envs/astroconda/lib
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/backends
# /
# /home
# /home/flavia
# /home/flavia/anaconda3
# /home/flavia/anaconda3/envs
# /home/flavia/anaconda3/envs/astroconda
# /home/flavia/anaconda3/envs/astroconda/lib
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib_inline
# /
# /home
# /home/flavia
# /home/flavia/anaconda3
# /home/flavia/anaconda3/envs
# /home/flavia/anaconda3/envs/astroconda
# /home/flavia/anaconda3/envs/astroconda/lib
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib_inline
# /
# /home
# /home/flavia
# /home/flavia/anaconda3
# /home/flavia/anaconda3/envs
# /home/flavia/anaconda3/envs/astroconda
# /home/flavia/anaconda3/envs/astroconda/lib
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/backends
# /
# /home
# /home/flavia
# /home/flavia/anaconda3
# /home/flavia/anaconda3/envs
# /home/flavia/anaconda3/envs/astroconda
# /home/flavia/anaconda3/envs/astroconda/lib
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib/backends
# /
# /home
# /home/flavia
# /home/flavia/anaconda3
# /home/flavia/anaconda3/envs
# /home/flavia/anaconda3/envs/astroconda
# /home/flavia/anaconda3/envs/astroconda/lib
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/matplotlib_inline
# /home/flavia/Portfolio/ML_projects/air-quality-forecasting/notebooks
# /home/flavia/Portfolio/ML_projects/air-quality-forecasting/notebooks
# /home/flavia/Portfolio/ML_projects/air-quality-forecasting/notebooks
# /home/flavia/Portfolio/ML_projects/air-quality-forecasting/notebooks
# /home/flavia/Portfolio/ML_projects/air-quality-forecasting/notebooks
# /home/flavia/Portfolio/ML_projects/air-quality-forecasting/notebooks
# /home/flavia/Portfolio/ML_projects/air-quality-forecasting/notebooks
# /home/flavia/Portfolio/ML_projects/air-quality-forecasting/notebooks
# /home/flavia/Portfolio/ML_projects/air-quality-forecasting/notebooks
# /home/flavia/anaconda3/envs/astroconda/lib/python37.zip
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/lib-dynload
#
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages
# /home/flavia/Portfolio/ML_projects/air-quality-forecasting/notebooks
# /home/flavia/anaconda3/envs/astroconda/lib/python37.zip
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/lib-dynload
#
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages
# /home/flavia/Portfolio/ML_projects/air-quality-forecasting/notebooks
# /home/flavia/anaconda3/envs/astroconda/lib/python37.zip
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/lib-dynload
#
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/picaso-3.2-py3.7.egg
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/virga_exo-0.4-py3.7.egg
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/shapely-2.0.4-py3.7-linux-x86_64.egg
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/fonttools-4.53.0-py3.7.egg
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/PyMieScatt-1.8.1.1-py3.7.egg
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/IPython/extensions
# /home/flavia/.ipython
# /home/flavia/Portfolio/ML_projects/air-quality-forecasting/notebooks
# /home/flavia/anaconda3/envs/astroconda/lib/python37.zip
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/lib-dynload
#
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/picaso-3.2-py3.7.egg
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/virga_exo-0.4-py3.7.egg
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/shapely-2.0.4-py3.7-linux-x86_64.egg
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/fonttools-4.53.0-py3.7.egg
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/PyMieScatt-1.8.1.1-py3.7.egg
# /home/flavia/anaconda3/envs/astroconda/lib/python3.7/site-packages/IPython/extensions
# /home/flavia/.ipython
# /home/flavia/Portfolio/ML_projects/air-quality-forecasting/notebooks
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/astroconda/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/anaconda3/envs/astroconda/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/anaconda3/envs/astroconda/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'NO2_clean'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_17844/2806740268.py in <module>
#      10 plt.plot(
#      11     df_long['datetime'],
# ---> 12     df_long['NO2_clean'],
#      13     label='NO₂ (clean)',
#      14     linewidth=1.5
#
# ~/anaconda3/envs/astroconda/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~/anaconda3/envs/astroconda/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'NO2_clean'
